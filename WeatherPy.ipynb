# %% [markdown]
# # WeatherPy
#
# ---

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 610

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?appid="+weather_api_key+"&units=metric&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url+city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        response = requests.get(city_url).json()
        #print(response)
        # Parse the JSON and retrieve data
        city_weather = response['weather'][0]['main']

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response['coord']['lat']
        city_lng = response['coord']['lon']
        city_max_temp = response['main']['temp_max']
        city_humidity = response['main']['humidity']
        city_clouds = response['clouds']['all']
        city_wind = response['wind']['speed']
        city_country = response['sys']['country']
        city_date = response['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | vicuna
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | kaitangata
# Processing Record 7 of Set 1 | saskylakh
# Processing Record 8 of Set 1 | dalian
# Processing Record 9 of Set 1 | kerema
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 1 | marchena
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | hobyo
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | saint george
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | pevek
# Processing Record 19 of Set 1 | namatanai
# Processing Record 20 of Set 1 | leningradskiy
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | yarmouth
# Processing Record 23 of Set 1 | hasaki
# Processing Record 24 of Set 1 | taoudenni
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | esperance
# Processing Record 27 of Set 1 | kahului
# Processing Record 28 of Set 1 | yulara
# Processing Record 29 of Set 1 | margaritesti
# City not found. Skipping...
# Processing Record 30 of Set 1 | haines junction
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | tazovskiy
# Processing Record 33 of Set 1 | san andres
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | lakes entrance
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | araouane
# Processing Record 39 of Set 1 | boa vista
# Processing Record 40 of Set 1 | valparaiso
# Processing Record 41 of Set 1 | cotonou
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | iberia
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | castro
# Processing Record 46 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | khandbari
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 50 of Set 1 | tura
# Processing Record 0 of Set 2 | bandarbeyla
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | svetlogorsk
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | liverpool
# Processing Record 5 of Set 2 | narsaq
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | cherskiy
# Processing Record 8 of Set 2 | nioro
# Processing Record 9 of Set 2 | tshikapa
# Processing Record 10 of Set 2 | tilichiki
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | westport
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | aykhal
# Processing Record 15 of Set 2 | inyonga
# Processing Record 16 of Set 2 | oron
# Processing Record 17 of Set 2 | black river
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | ferrol
# Processing Record 21 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 2 | souillac
# Processing Record 23 of Set 2 | buta
# Processing Record 24 of Set 2 | beringovskiy
# Processing Record 25 of Set 2 | charters towers
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | yol
# Processing Record 28 of Set 2 | sao filipe
# Processing Record 29 of Set 2 | tiksi
# Processing Record 30 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 31 of Set 2 | mantua
# Processing Record 32 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 2 | majene
# Processing Record 34 of Set 2 | plaeng yao
# Processing Record 35 of Set 2 | talnakh
# Processing Record 36 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 2 | touros
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | kumluca
# Processing Record 40 of Set 2 | hilo
# Processing Record 41 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 2 | labuhan
# Processing Record 43 of Set 2 | karratha
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | georgetown
# Processing Record 46 of Set 2 | salalah
# Processing Record 47 of Set 2 | enid
# Processing Record 48 of Set 2 | kulhudhuffushi
# Processing Record 49 of Set 2 | mount isa
# Processing Record 0 of Set 3 | cabo san lucas
# Processing Record 1 of Set 3 | clyde river
# Processing Record 2 of Set 3 | kavarskas
# Processing Record 3 of Set 3 | roald
# Processing Record 4 of Set 3 | quang ngai
# Processing Record 5 of Set 3 | saint-georges
# Processing Record 6 of Set 3 | cayenne
# Processing Record 7 of Set 3 | caravelas
# Processing Record 8 of Set 3 | ampanihy
# Processing Record 9 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 10 of Set 3 | kisanga
# Processing Record 11 of Set 3 | bengkulu
# Processing Record 12 of Set 3 | tautira
# Processing Record 13 of Set 3 | giyani
# Processing Record 14 of Set 3 | churachandpur
# Processing Record 15 of Set 3 | port elizabeth
# Processing Record 16 of Set 3 | zaraza
# Processing Record 17 of Set 3 | vardo
# Processing Record 18 of Set 3 | alice springs
# Processing Record 19 of Set 3 | hermanus
# Processing Record 20 of Set 3 | port alfred
# Processing Record 21 of Set 3 | kachkanar
# Processing Record 22 of Set 3 | husavik
# Processing Record 23 of Set 3 | cidreira
# Processing Record 24 of Set 3 | rundu
# Processing Record 25 of Set 3 | balclutha
# Processing Record 26 of Set 3 | melito di porto salvo
# Processing Record 27 of Set 3 | colac
# Processing Record 28 of Set 3 | ust-kuyga
# Processing Record 29 of Set 3 | maputo
# Processing Record 30 of Set 3 | aswan
# Processing Record 31 of Set 3 | severo-kurilsk
# Processing Record 32 of Set 3 | port lincoln
# Processing Record 33 of Set 3 | sola
# Processing Record 34 of Set 3 | kavieng
# Processing Record 35 of Set 3 | noumea
# Processing Record 36 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 3 | yar-sale
# Processing Record 38 of Set 3 | lorengau
# Processing Record 39 of Set 3 | katsuura
# Processing Record 40 of Set 3 | la ronge
# Processing Record 41 of Set 3 | qujing
# Processing Record 42 of Set 3 | longyearbyen
# Processing Record 43 of Set 3 | saint-philippe
# Processing Record 44 of Set 3 | arraial do cabo
# Processing Record 45 of Set 3 | saint-pierre
# Processing Record 46 of Set 3 | sioux lookout
# Processing Record 47 of Set 3 | pouembout
# Processing Record 48 of Set 3 | ballina
# Processing Record 49 of Set 3 | mizan teferi
# Processing Record 0 of Set 4 | panayakan
# City not found. Skipping...
# Processing Record 1 of Set 4 | belmonte
# Processing Record 2 of Set 4 | kungurtug
# Processing Record 3 of Set 4 | pisco
# Processing Record 4 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 6 of Set 4 | kropotkin
# Processing Record 7 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 8 of Set 4 | khatanga
# Processing Record 9 of Set 4 | marsabit
# Processing Record 10 of Set 4 | hami
# Processing Record 11 of Set 4 | faanui
# Processing Record 12 of Set 4 | sinop
# Processing Record 13 of Set 4 | bay roberts
# Processing Record 14 of Set 4 | moroni
# Processing Record 15 of Set 4 | aklavik
# Processing Record 16 of Set 4 | west bay
# Processing Record 17 of Set 4 | oro valley
# Processing Record 18 of Set 4 | dikson
# Processing Record 19 of Set 4 | lompoc
# Processing Record 20 of Set 4 | luderitz
# Processing Record 21 of Set 4 | lebu
# Processing Record 22 of Set 4 | palmer
# Processing Record 23 of Set 4 | ayer itam
# City not found. Skipping...
# Processing Record 24 of Set 4 | galion
# Processing Record 25 of Set 4 | houlton
# Processing Record 26 of Set 4 | oranjemund
# Processing Record 27 of Set 4 | barroso
# Processing Record 28 of Set 4 | tuatapere
# Processing Record 29 of Set 4 | nantucket
# Processing Record 30 of Set 4 | kissidougou
# Processing Record 31 of Set 4 | isangel
# Processing Record 32 of Set 4 | hambantota
# Processing Record 33 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 4 | pingxiang
# Processing Record 35 of Set 4 | richards bay
# Processing Record 36 of Set 4 | alofi
# Processing Record 37 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 38 of Set 4 | broome
# Processing Record 39 of Set 4 | sao joao da barra
# Processing Record 40 of Set 4 | vinkovci
# Processing Record 41 of Set 4 | magadan
# Processing Record 42 of Set 4 | te anau
# Processing Record 43 of Set 4 | manokwari
# Processing Record 44 of Set 4 | olafsvik
# Processing Record 45 of Set 4 | udachnyy
# Processing Record 46 of Set 4 | egvekinot
# Processing Record 47 of Set 4 | asau
# Processing Record 48 of Set 4 | unye
# City not found. Skipping...
# Processing Record 49 of Set 4 | nanortalik
# Processing Record 0 of Set 5 | codrington
# Processing Record 1 of Set 5 | pangai
# Processing Record 2 of Set 5 | kant
# Processing Record 3 of Set 5 | kuzhener
# Processing Record 4 of Set 5 | hofn
# Processing Record 5 of Set 5 | burnie
# Processing Record 6 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 5 | leua
# Processing Record 8 of Set 5 | airai
# Processing Record 9 of Set 5 | bizhbulyak
# Processing Record 10 of Set 5 | nome
# Processing Record 11 of Set 5 | kismayo
# Processing Record 12 of Set 5 | shakiso
# Processing Record 13 of Set 5 | manitowoc
# Processing Record 14 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 5 | two rivers
# Processing Record 16 of Set 5 | lixourion
# Processing Record 17 of Set 5 | chiredzi
# Processing Record 18 of Set 5 | saravan
# Processing Record 19 of Set 5 | new norfolk
# Processing Record 20 of Set 5 | voh
# Processing Record 21 of Set 5 | saeby
# Processing Record 22 of Set 5 | bagn
# Processing Record 23 of Set 5 | puerto escondido
# Processing Record 24 of Set 5 | spearfish
# Processing Record 25 of Set 5 | lacolle
# Processing Record 26 of Set 5 | guerrero negro
# Processing Record 27 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 28 of Set 5 | viedma
# Processing Record 29 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 30 of Set 5 | nikolskoye
# Processing Record 31 of Set 5 | bac lieu
# Processing Record 32 of Set 5 | sapa
# Processing Record 33 of Set 5 | meulaboh
# Processing Record 34 of Set 5 | mujiayingzi
# Processing Record 35 of Set 5 | skorodnoye
# Processing Record 36 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 5 | ostrovnoy
# Processing Record 38 of Set 5 | batagay
# Processing Record 39 of Set 5 | bambanglipuro
# Processing Record 40 of Set 5 | avarua
# Processing Record 41 of Set 5 | puerto gaitan
# Processing Record 42 of Set 5 | wukari
# Processing Record 43 of Set 5 | provideniya
# Processing Record 44 of Set 5 | port hardy
# Processing Record 45 of Set 5 | sonqor
# Processing Record 46 of Set 5 | norman wells
# Processing Record 47 of Set 5 | iqaluit
# Processing Record 48 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 5 | cerritos
# Processing Record 0 of Set 6 | monrovia
# Processing Record 1 of Set 6 | agadez
# Processing Record 2 of Set 6 | pauini
# Processing Record 3 of Set 6 | phumi samraong
# City not found. Skipping...
# Processing Record 4 of Set 6 | mineiros
# Processing Record 5 of Set 6 | vengerovo
# Processing Record 6 of Set 6 | bodden town
# Processing Record 7 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 8 of Set 6 | ponta do sol
# Processing Record 9 of Set 6 | beloha
# Processing Record 10 of Set 6 | buchanan
# Processing Record 11 of Set 6 | ciudad ojeda
# Processing Record 12 of Set 6 | sabang
# Processing Record 13 of Set 6 | mataram
# Processing Record 14 of Set 6 | talara
# Processing Record 15 of Set 6 | ilulissat
# Processing Record 16 of Set 6 | sitka
# Processing Record 17 of Set 6 | rosario do sul
# Processing Record 18 of Set 6 | kruisfontein
# Processing Record 19 of Set 6 | dragomiresti
# Processing Record 20 of Set 6 | taksimo
# Processing Record 21 of Set 6 | erzin
# Processing Record 22 of Set 6 | ribeira grande
# Processing Record 23 of Set 6 | shiraz
# Processing Record 24 of Set 6 | berezovyy
# Processing Record 25 of Set 6 | eureka
# Processing Record 26 of Set 6 | jyvaskyla
# Processing Record 27 of Set 6 | mayo
# Processing Record 28 of Set 6 | dingle
# Processing Record 29 of Set 6 | itaituba
# Processing Record 30 of Set 6 | san luis
# Processing Record 31 of Set 6 | gizo
# Processing Record 32 of Set 6 | mahibadhoo
# Processing Record 33 of Set 6 | thinadhoo
# Processing Record 34 of Set 6 | ketchikan
# Processing Record 35 of Set 6 | mar del plata
# Processing Record 36 of Set 6 | zonguldak
# Processing Record 37 of Set 6 | upernavik
# Processing Record 38 of Set 6 | vila franca do campo
# Processing Record 39 of Set 6 | kodiak
# Processing Record 40 of Set 6 | gat
# Processing Record 41 of Set 6 | sri aman
# Processing Record 42 of Set 6 | sorland
# Processing Record 43 of Set 6 | mahebourg
# Processing Record 44 of Set 6 | san carlos de bariloche
# Processing Record 45 of Set 6 | bustonkala
# City not found. Skipping...
# Processing Record 46 of Set 6 | celestun
# Processing Record 47 of Set 6 | conceicao do araguaia
# Processing Record 48 of Set 6 | lamu
# Processing Record 49 of Set 6 | rovaniemi
# Processing Record 0 of Set 7 | andra
# Processing Record 1 of Set 7 | ahipara
# Processing Record 2 of Set 7 | menongue
# Processing Record 3 of Set 7 | hermosillo
# Processing Record 4 of Set 7 | laguna
# Processing Record 5 of Set 7 | salym
# Processing Record 6 of Set 7 | poum
# Processing Record 7 of Set 7 | chokurdakh
# Processing Record 8 of Set 7 | sechura
# Processing Record 9 of Set 7 | ngunguru
# Processing Record 10 of Set 7 | makung
# City not found. Skipping...
# Processing Record 11 of Set 7 | inverell
# Processing Record 12 of Set 7 | upata
# Processing Record 13 of Set 7 | sinnamary
# Processing Record 14 of Set 7 | constitucion
# Processing Record 15 of Set 7 | mbini
# Processing Record 16 of Set 7 | belyy yar
# Processing Record 17 of Set 7 | dudinka
# Processing Record 18 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 7 | yemtsa
# Processing Record 20 of Set 7 | colares
# Processing Record 21 of Set 7 | adrar
# Processing Record 22 of Set 7 | villa bruzual
# Processing Record 23 of Set 7 | bonthe
# Processing Record 24 of Set 7 | manwath
# City not found. Skipping...
# Processing Record 25 of Set 7 | fortuna
# Processing Record 26 of Set 7 | ancud
# Processing Record 27 of Set 7 | muros
# Processing Record 28 of Set 7 | praia
# Processing Record 29 of Set 7 | hualmay
# Processing Record 30 of Set 7 | lagoa
# Processing Record 31 of Set 7 | diego de almagro
# Processing Record 32 of Set 7 | lebrija
# Processing Record 33 of Set 7 | kirakira
# Processing Record 34 of Set 7 | coihaique
# Processing Record 35 of Set 7 | lundazi
# Processing Record 36 of Set 7 | mbanza-ngungu
# Processing Record 37 of Set 7 | oktyabrskoye
# Processing Record 38 of Set 7 | svetlyy
# Processing Record 39 of Set 7 | sisimiut
# Processing Record 40 of Set 7 | brae
# Processing Record 41 of Set 7 | sambava
# Processing Record 42 of Set 7 | ahvaz
# Processing Record 43 of Set 7 | carnarvon
# Processing Record 44 of Set 7 | zhangye
# Processing Record 45 of Set 7 | kaitong
# Processing Record 46 of Set 7 | progreso
# Processing Record 47 of Set 7 | aden
# Processing Record 48 of Set 7 | wanaka
# Processing Record 49 of Set 7 | bathsheba
# Processing Record 0 of Set 8 | khakhea
# Processing Record 1 of Set 8 | ambon
# Processing Record 2 of Set 8 | talaya
# Processing Record 3 of Set 8 | platteville
# Processing Record 4 of Set 8 | tres arroyos
# Processing Record 5 of Set 8 | lata
# Processing Record 6 of Set 8 | akyab
# Processing Record 7 of Set 8 | krasnoselkup
# Processing Record 8 of Set 8 | kalomo
# City not found. Skipping...
# Processing Record 9 of Set 8 | anqing
# Processing Record 10 of Set 8 | kununurra
# Processing Record 11 of Set 8 | ayapel
# Processing Record 12 of Set 8 | nacala
# Processing Record 13 of Set 8 | diamantina
# Processing Record 14 of Set 8 | chute-aux-outardes
# Processing Record 15 of Set 8 | acapulco
# Processing Record 16 of Set 8 | kamenka
# Processing Record 17 of Set 8 | ambilobe
# Processing Record 18 of Set 8 | sobolevo
# Processing Record 19 of Set 8 | torbay
# Processing Record 20 of Set 8 | atyrau
# Processing Record 21 of Set 8 | raga
# Processing Record 22 of Set 8 | lavrentiya
# Processing Record 23 of Set 8 | mecca
# Processing Record 24 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 8 | moshi
# Processing Record 26 of Set 8 | paamiut
# Processing Record 27 of Set 8 | lisakovsk
# Processing Record 28 of Set 8 | sudogda
# Processing Record 29 of Set 8 | chai badan
# Processing Record 30 of Set 8 | komsomolskiy
# Processing Record 31 of Set 8 | mumford
# Processing Record 32 of Set 8 | soure
# Processing Record 33 of Set 8 | pekan
# Processing Record 34 of Set 8 | naze
# Processing Record 35 of Set 8 | bajil
# Processing Record 36 of Set 8 | mount pleasant
# Processing Record 37 of Set 8 | kobryn
# Processing Record 38 of Set 8 | chuy
# Processing Record 39 of Set 8 | krasnogorsk
# Processing Record 40 of Set 8 | qidong
# Processing Record 41 of Set 8 | bethel
# Processing Record 42 of Set 8 | bichura
# Processing Record 43 of Set 8 | glubokoe
# City not found. Skipping...
# Processing Record 44 of Set 8 | melville
# Processing Record 45 of Set 8 | zabaykalsk
# Processing Record 46 of Set 8 | bubaque
# Processing Record 47 of Set 8 | vila velha
# Processing Record 48 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 8 | almaznyy
# Processing Record 0 of Set 9 | san quintin
# Processing Record 1 of Set 9 | nha trang
# Processing Record 2 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 3 of Set 9 | toora-khem
# Processing Record 4 of Set 9 | hwange
# Processing Record 5 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 9 | lusambo
# Processing Record 7 of Set 9 | nabha
# Processing Record 8 of Set 9 | mackay
# Processing Record 9 of Set 9 | ust-kut
# Processing Record 10 of Set 9 | santa rosa
# Processing Record 11 of Set 9 | bairiki
# Processing Record 12 of Set 9 | novikovo
# Processing Record 13 of Set 9 | tezu
# Processing Record 14 of Set 9 | valdosta
# Processing Record 15 of Set 9 | klaksvik
# Processing Record 16 of Set 9 | urumqi
# Processing Record 17 of Set 9 | verkhnevilyuysk
# Processing Record 18 of Set 9 | conde
# Processing Record 19 of Set 9 | ishigaki
# Processing Record 20 of Set 9 | breytovo
# Processing Record 21 of Set 9 | orange
# Processing Record 22 of Set 9 | strelka
# Processing Record 23 of Set 9 | rocha
# Processing Record 24 of Set 9 | reefton
# City not found. Skipping...
# Processing Record 25 of Set 9 | tocopilla
# Processing Record 26 of Set 9 | havre-saint-pierre
# Processing Record 27 of Set 9 | candolim
# Processing Record 28 of Set 9 | presidencia roque saenz pena
# Processing Record 29 of Set 9 | namibe
# Processing Record 30 of Set 9 | shitanjing
# Processing Record 31 of Set 9 | vitim
# Processing Record 32 of Set 9 | hay river
# Processing Record 33 of Set 9 | almeirim
# Processing Record 34 of Set 9 | avera
# Processing Record 35 of Set 9 | anadyr
# Processing Record 36 of Set 9 | ubatuba
# Processing Record 37 of Set 9 | ammon
# Processing Record 38 of Set 9 | port hawkesbury
# Processing Record 39 of Set 9 | oussouye
# Processing Record 40 of Set 9 | baykit
# Processing Record 41 of Set 9 | doka
# Processing Record 42 of Set 9 | altay
# Processing Record 43 of Set 9 | jiroft
# City not found. Skipping...
# Processing Record 44 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 45 of Set 9 | midland
# Processing Record 46 of Set 9 | mananjary
# Processing Record 47 of Set 9 | cabedelo
# Processing Record 48 of Set 9 | tambun
# Processing Record 49 of Set 9 | college
# Processing Record 0 of Set 10 | markova
# Processing Record 1 of Set 10 | saint-augustin
# Processing Record 2 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 10 | tambilil
# Processing Record 4 of Set 10 | sistranda
# Processing Record 5 of Set 10 | laiya
# Processing Record 6 of Set 10 | laon
# Processing Record 7 of Set 10 | galle
# Processing Record 8 of Set 10 | gzhatsk
# City not found. Skipping...
# Processing Record 9 of Set 10 | verkh-usugli
# Processing Record 10 of Set 10 | port moresby
# Processing Record 11 of Set 10 | warmbad
# Processing Record 12 of Set 10 | liepaja
# Processing Record 13 of Set 10 | morondava
# Processing Record 14 of Set 10 | comodoro rivadavia
# Processing Record 15 of Set 10 | garh maharaja
# Processing Record 16 of Set 10 | weligama
# Processing Record 17 of Set 10 | arcata
# Processing Record 18 of Set 10 | ponta delgada
# Processing Record 19 of Set 10 | rheinfelden
# Processing Record 20 of Set 10 | shanghai
# Processing Record 21 of Set 10 | great yarmouth
# Processing Record 22 of Set 10 | aksu
# Processing Record 23 of Set 10 | chernyshkovskiy
# Processing Record 24 of Set 10 | waiouru
# Processing Record 25 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 26 of Set 10 | el estor
# Processing Record 27 of Set 10 | tynda
# Processing Record 28 of Set 10 | wilmington island
# Processing Record 29 of Set 10 | vostok
# Processing Record 30 of Set 10 | sibolga
# Processing Record 31 of Set 10 | pacific grove
# Processing Record 32 of Set 10 | samarai
# Processing Record 33 of Set 10 | kautokeino
# Processing Record 34 of Set 10 | karaton
# Processing Record 35 of Set 10 | agadir
# Processing Record 36 of Set 10 | dawlatabad
# Processing Record 37 of Set 10 | yueyang
# Processing Record 38 of Set 10 | khandyga
# Processing Record 39 of Set 10 | jinchang
# Processing Record 40 of Set 10 | montepuez
# Processing Record 41 of Set 10 | magadi
# Processing Record 42 of Set 10 | batagay-alyta
# Processing Record 43 of Set 10 | erenhot
# Processing Record 44 of Set 10 | tangier
# Processing Record 45 of Set 10 | bago
# Processing Record 46 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 47 of Set 10 | alipur
# Processing Record 48 of Set 10 | derzhavinsk
# Processing Record 49 of Set 10 | basco
# Processing Record 0 of Set 11 | auki
# Processing Record 1 of Set 11 | russell
# Processing Record 2 of Set 11 | zhanakorgan
# Processing Record 3 of Set 11 | luau
# Processing Record 4 of Set 11 | itarema
# Processing Record 5 of Set 11 | alexandria
# Processing Record 6 of Set 11 | san pedro de macoris
# Processing Record 7 of Set 11 | geraldton
# Processing Record 8 of Set 11 | chapais
# Processing Record 9 of Set 11 | ilebo
# Processing Record 10 of Set 11 | gerash
# Processing Record 11 of Set 11 | raudeberg
# Processing Record 12 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 13 of Set 11 | buala
# Processing Record 14 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 11 | marsh harbour
# Processing Record 17 of Set 11 | falavarjan
# Processing Record 18 of Set 11 | port-cartier
# Processing Record 19 of Set 11 | ayios kirikos
# City not found. Skipping...
# Processing Record 20 of Set 11 | pandan niog
# Processing Record 21 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 11 | rawson
# Processing Record 23 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 11 | keshabpur
# Processing Record 25 of Set 11 | agirish
# Processing Record 26 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 11 | vagay
# Processing Record 28 of Set 11 | prattville
# Processing Record 29 of Set 11 | hammel
# Processing Record 30 of Set 11 | vila do maio
# Processing Record 31 of Set 11 | nueva concepcion
# Processing Record 32 of Set 11 | vidim
# Processing Record 33 of Set 11 | seoul
# Processing Record 34 of Set 11 | lewistown
# Processing Record 35 of Set 11 | kenai
# Processing Record 36 of Set 11 | jumla
# Processing Record 37 of Set 11 | kita
# Processing Record 38 of Set 11 | ossora
# Processing Record 39 of Set 11 | goundam
# Processing Record 40 of Set 11 | ustyuzhna
# Processing Record 41 of Set 11 | blagoveshchensk
# Processing Record 42 of Set 11 | vanimo
# Processing Record 43 of Set 11 | flin flon
# Processing Record 44 of Set 11 | saldanha
# Processing Record 45 of Set 11 | pangoa
# Processing Record 46 of Set 11 | sulat
# Processing Record 47 of Set 11 | elwood
# Processing Record 48 of Set 11 | sarangani
# Processing Record 49 of Set 11 | eyl
# Processing Record 0 of Set 12 | jhalida
# Processing Record 1 of Set 12 | linhares
# Processing Record 2 of Set 12 | chifeng
# Processing Record 3 of Set 12 | frolovo
# Processing Record 4 of Set 12 | coquimbo
# Processing Record 5 of Set 12 | sept-iles
# Processing Record 6 of Set 12 | kalmunai
# Processing Record 7 of Set 12 | lasa
# Processing Record 8 of Set 12 | qaqortoq
# Processing Record 9 of Set 12 | udalguri
# Processing Record 10 of Set 12 | kavaratti
# Processing Record 11 of Set 12 | asfi
# Processing Record 12 of Set 12 | sumkino
# Processing Record 13 of Set 12 | porbandar
# Processing Record 14 of Set 12 | gilgit
# Processing Record 15 of Set 12 | bonavista
# Processing Record 16 of Set 12 | zhigansk
# Processing Record 17 of Set 12 | leshukonskoye
# Processing Record 18 of Set 12 | togur
# Processing Record 19 of Set 12 | gaozhou
# Processing Record 20 of Set 12 | kajaani
# Processing Record 21 of Set 12 | luwuk
# Processing Record 22 of Set 12 | antonina
# Processing Record 23 of Set 12 | cap-aux-meules
# Processing Record 24 of Set 12 | talcahuano
# Processing Record 25 of Set 12 | naliya
# Processing Record 26 of Set 12 | kysyl-syr
# Processing Record 27 of Set 12 | kidal
# Processing Record 28 of Set 12 | moussoro
# Processing Record 29 of Set 12 | waingapu
# Processing Record 30 of Set 12 | aranos
# Processing Record 31 of Set 12 | olinda
# Processing Record 32 of Set 12 | amga
# Processing Record 33 of Set 12 | vung tau
# Processing Record 34 of Set 12 | weatherford
# Processing Record 35 of Set 12 | srednekolymsk
# Processing Record 36 of Set 12 | teya
# Processing Record 37 of Set 12 | durango
# Processing Record 38 of Set 12 | cayambe
# Processing Record 39 of Set 12 | jeremie
# Processing Record 40 of Set 12 | los llanos de aridane
# Processing Record 41 of Set 12 | ondjiva
# Processing Record 42 of Set 12 | stromness
# Processing Record 43 of Set 12 | homer
# Processing Record 44 of Set 12 | antalaha
# Processing Record 45 of Set 12 | guarapari
# Processing Record 46 of Set 12 | sovetskaya gavan
# Processing Record 47 of Set 12 | digby
# Processing Record 48 of Set 12 | henties bay
# Processing Record 49 of Set 12 | luena
# Processing Record 0 of Set 13 | salinas
# Processing Record 1 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 2 of Set 13 | montlucon
# Processing Record 3 of Set 13 | beihai
# Processing Record 4 of Set 13 | san patricio
# Processing Record 5 of Set 13 | palmeirais
# Processing Record 6 of Set 13 | tiarei
# Processing Record 7 of Set 13 | burgos
# Processing Record 8 of Set 13 | san nicolas
# Processing Record 9 of Set 13 | kalangala
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          557
# Lat           557
# Lng           557
# Max Temp      557
# Humidity      557
# Cloudiness    557
# Wind Speed    557
# Country       557
# Date          557
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      mataura -46.1927  168.8643     11.38        80          92        3.98
# 1      rikitea -23.1203 -134.9692     25.42        69          83        5.06
# 2  east london -33.0153   27.9116     15.52        82           0        3.09
# 3       vicuna -30.0319  -70.7081      9.85        62          77        0.33
# 4      ushuaia -54.8000  -68.3000      4.81        75          75        7.20
#
#   Country        Date
# 0      NZ  1681359721
# 1      PF  1681359721
# 2      ZA  1681359721
# 3      CL  1681359721
# 4      AR  1681359722

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            mataura -46.1927  168.8643     11.38        80          92
# 1            rikitea -23.1203 -134.9692     25.42        69          83
# 2        east london -33.0153   27.9116     15.52        82           0
# 3             vicuna -30.0319  -70.7081      9.85        62          77
# 4            ushuaia -54.8000  -68.3000      4.81        75          75
#
#          Wind Speed Country        Date
# City_ID
# 0              3.98      NZ  1681359721
# 1              5.06      PF  1681359721
# 2              3.09      ZA  1681359721
# 3              0.33      CL  1681359721
# 4              7.20      AR  1681359722

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot('Lat','Max Temp',kind='scatter')
# Incorporate the other graph properties
max_date = pd.to_datetime(city_data_df['Date'].max(), unit='s').date()
plt.title("Latitude vs Max Temperature ("+str(max_date)+")")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (C)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
city_data_df.plot('Lat','Humidity',kind='scatter')

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity ("+str(max_date)+")")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot('Lat','Cloudiness',kind='scatter')

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness ("+str(max_date)+")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot('Lat','Wind Speed',kind='scatter')

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed ("+str(max_date)+")")
plt.xlabel("city Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def draw_regression_line(x_values,y_values,x,y):
    slope, intercept, rval, pval, std_err = linregress(x_values,y_values)
    print(f"The r-squared value is: {rval**2}")
    fit = slope * x_values  + intercept
    line_eq=f"y = {round(slope,2)}x + {round(intercept,2)}"
    plt.scatter(x_values,y_values)
    plt.annotate(line_eq,(x,y),fontsize=15,color="red")
    plt.xlabel("Latitude")
    return plt.plot(x_values,fit,'-', color='r')

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0,:]
# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 6        saskylakh  71.9167  114.0833    -10.87        75          87
# 7           dalian  38.9122  121.6022     17.96        19           0
# 10        marchena  37.3290   -5.4168     12.31        71          31
# 11         qaanaaq  77.4840  -69.3632    -17.59        68           0
# 12           hobyo   5.3505   48.5268     28.16        73         100
#
#          Wind Speed Country        Date
# City_ID
# 6              6.90      RU  1681359722
# 7              6.00      CN  1681359722
# 10             1.46      ES  1681359725
# 11             1.93      GL  1681359725
# 12             3.47      SO  1681359725

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0,:]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            mataura -46.1927  168.8643     11.38        80          92
# 1            rikitea -23.1203 -134.9692     25.42        69          83
# 2        east london -33.0153   27.9116     15.52        82           0
# 3             vicuna -30.0319  -70.7081      9.85        62          77
# 4            ushuaia -54.8000  -68.3000      4.81        75          75
#
#          Wind Speed Country        Date
# City_ID
# 0              3.98      NZ  1681359721
# 1              5.06      PF  1681359721
# 2              3.09      ZA  1681359721
# 3              0.33      CL  1681359721
# 4              7.20      AR  1681359722

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
draw_regression_line(northern_hemi_df['Lat'],northern_hemi_df["Max Temp"],10,-20)
plt.ylabel("Max Temperature")
plt.show()
# Out:
# The r-squared value is: 0.783801229298485

# %%
# Linear regression on Southern Hemisphere
draw_regression_line(southern_hemi_df['Lat'],southern_hemi_df["Max Temp"],-55,30)
plt.ylabel("Max Temperature")
plt.show()
# Out:
# The r-squared value is: 0.5067981882846627

# %% [markdown]
# **Discussion about the linear relationship:** Temperature variations in the northern hemishpere have a higher linear relationship with latititudes (74.62%) as compared to the relationship between temperatures and latitude in the southern hemisphere (42.42%).

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
draw_regression_line(northern_hemi_df['Lat'],northern_hemi_df["Humidity"],40,0)
plt.ylabel("Humidity")
plt.show()
# Out:
# The r-squared value is: 0.04254840508029445

# %%
# Southern Hemisphere
draw_regression_line(southern_hemi_df['Lat'],southern_hemi_df["Humidity"],-50,20)
plt.ylabel("Humidity")
plt.show()
# Out:
# The r-squared value is: 0.045857685825783895

# %% [markdown]
# **Discussion about the linear relationship:** Only 12.21% of variations in humidity in the northern hemisphere are accounted for by the change in latitude while only 8.58% of hunidity variations in the southern hemisphere and be accounted for changes in latitude. Small linear relationship between humidity and latitude in both the hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
#Northern Hemisphere
draw_regression_line(northern_hemi_df['Lat'],northern_hemi_df["Cloudiness"],40,55)
plt.ylabel("Cloudiness")
plt.show()
# Out:
# The r-squared value is: 0.010165492327583433

# %%
#Southern Hemisphere
draw_regression_line(southern_hemi_df['Lat'],southern_hemi_df["Cloudiness"],-52,60)
plt.ylabel("Cloudiness")
plt.show()
# Out:
# The r-squared value is: 0.039165740263084586

# %% [markdown]
# **Discussion about the linear relationship:** Only 4.42% of cloudiness variations can be accounted for by changes in the northern hemishpere lattitudes, while onlt 13% of cloudiness variations can be accounted for by the changes in a Southern hemisphere latitude changes, very small linear relationship between cloudiness and latitude in both the hemishperes.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
draw_regression_line(northern_hemi_df['Lat'],northern_hemi_df["Wind Speed"],10,12)
plt.ylabel("Wind Speed")
plt.show()
# Out:
# The r-squared value is: 0.02821146114352929

# %%
# Southern Hemisphere
draw_regression_line(southern_hemi_df['Lat'],southern_hemi_df["Wind Speed"],-50,9)
plt.ylabel("Wind Speed")
plt.show()
# Out:
# The r-squared value is: 0.05363337040020692

# %% [markdown]
# **Discussion about the linear relationship:** Only 0.96% of variations in wind speed is accounted for with change in the northern hemisphere latitdude and 7.73% of variations in wind speed is accounted for changes in the southern hemisphere latitude, very low linear relationship between wind speed and latitude in both the hemispheres.
