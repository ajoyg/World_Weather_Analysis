# %% [markdown]
# # WeatherPy
#
# ---

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 609

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?appid="+weather_api_key+"&units=metric&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url+city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        response = requests.get(city_url).json()
        #print(response)
        # Parse the JSON and retrieve data
        city_weather = response['weather'][0]['main']

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response['coord']['lat']
        city_lng = response['coord']['lon']
        city_max_temp = response['main']['temp_max']
        city_humidity = response['main']['humidity']
        city_clouds = response['clouds']['all']
        city_wind = response['wind']['speed']
        city_country = response['sys']['country']
        city_date = response['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | maragogi
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | birjand
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | port-gentil
# Processing Record 6 of Set 1 | narsaq
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | meadow lake
# Processing Record 10 of Set 1 | solnechnyy
# Processing Record 11 of Set 1 | jacareacanga
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | busayra
# Processing Record 16 of Set 1 | chinhoyi
# Processing Record 17 of Set 1 | bukachacha
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | watsa
# Processing Record 20 of Set 1 | klaksvik
# Processing Record 21 of Set 1 | sahrak
# City not found. Skipping...
# Processing Record 22 of Set 1 | falmouth
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | khatanga
# Processing Record 25 of Set 1 | sierra vista
# Processing Record 26 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | gimli
# Processing Record 29 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 1 | del rio
# Processing Record 31 of Set 1 | bathsheba
# Processing Record 32 of Set 1 | kavieng
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | bengkulu
# Processing Record 36 of Set 1 | goldsboro
# Processing Record 37 of Set 1 | leningradskiy
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | synya
# Processing Record 40 of Set 1 | tanete
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | khromtau
# Processing Record 44 of Set 1 | avera
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | muros
# Processing Record 48 of Set 1 | diban
# Processing Record 49 of Set 1 | kurilsk
# Processing Record 50 of Set 1 | gryfino
# Processing Record 0 of Set 2 | paragominas
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | arona
# Processing Record 3 of Set 2 | chokurdakh
# Processing Record 4 of Set 2 | stromness
# Processing Record 5 of Set 2 | katsuura
# Processing Record 6 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 2 | bambous virieux
# Processing Record 8 of Set 2 | matara
# Processing Record 9 of Set 2 | porto belo
# Processing Record 10 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 2 | ponta do sol
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | iqaluit
# Processing Record 15 of Set 2 | zhanaozen
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | paka
# Processing Record 18 of Set 2 | isangel
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | pisco
# Processing Record 21 of Set 2 | bitung
# Processing Record 22 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 2 | saint-georges
# Processing Record 24 of Set 2 | dukat
# Processing Record 25 of Set 2 | bardiyah
# Processing Record 26 of Set 2 | itamarandiba
# Processing Record 27 of Set 2 | barahona
# Processing Record 28 of Set 2 | laguna
# Processing Record 29 of Set 2 | port alfred
# Processing Record 30 of Set 2 | punta arenas
# Processing Record 31 of Set 2 | den helder
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | holme
# Processing Record 34 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 2 | hofn
# Processing Record 36 of Set 2 | seymchan
# Processing Record 37 of Set 2 | kavaratti
# Processing Record 38 of Set 2 | esperance
# Processing Record 39 of Set 2 | dingle
# Processing Record 40 of Set 2 | tasiilaq
# Processing Record 41 of Set 2 | kodiak
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | charters towers
# Processing Record 44 of Set 2 | yar-sale
# Processing Record 45 of Set 2 | thunder bay
# Processing Record 46 of Set 2 | mar del plata
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | tiksi
# Processing Record 49 of Set 2 | bethel
# Processing Record 0 of Set 3 | faanui
# Processing Record 1 of Set 3 | chernyshevskiy
# Processing Record 2 of Set 3 | pevek
# Processing Record 3 of Set 3 | hami
# Processing Record 4 of Set 3 | tuatapere
# Processing Record 5 of Set 3 | deputatskiy
# Processing Record 6 of Set 3 | souillac
# Processing Record 7 of Set 3 | puerto ayora
# Processing Record 8 of Set 3 | fare
# Processing Record 9 of Set 3 | balabac
# Processing Record 10 of Set 3 | jeremie
# Processing Record 11 of Set 3 | constitucion
# Processing Record 12 of Set 3 | namatanai
# Processing Record 13 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 3 | kruisfontein
# Processing Record 15 of Set 3 | castro
# Processing Record 16 of Set 3 | roma
# Processing Record 17 of Set 3 | provideniya
# Processing Record 18 of Set 3 | geraldton
# Processing Record 19 of Set 3 | okhotsk
# Processing Record 20 of Set 3 | burla
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | itaituba
# Processing Record 23 of Set 3 | kirakira
# Processing Record 24 of Set 3 | amahai
# Processing Record 25 of Set 3 | jamestown
# Processing Record 26 of Set 3 | kedrovyy
# Processing Record 27 of Set 3 | kemin
# Processing Record 28 of Set 3 | bani walid
# Processing Record 29 of Set 3 | boyuibe
# Processing Record 30 of Set 3 | tilichiki
# Processing Record 31 of Set 3 | port keats
# Processing Record 32 of Set 3 | oranjemund
# Processing Record 33 of Set 3 | klamath falls
# Processing Record 34 of Set 3 | rawson
# Processing Record 35 of Set 3 | pasni
# Processing Record 36 of Set 3 | tazovskiy
# Processing Record 37 of Set 3 | kapaa
# Processing Record 38 of Set 3 | fallon
# Processing Record 39 of Set 3 | harper
# Processing Record 40 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 3 | hasaki
# Processing Record 42 of Set 3 | lorengau
# Processing Record 43 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 3 | ino
# Processing Record 45 of Set 3 | copiapo
# Processing Record 46 of Set 3 | bonavista
# Processing Record 47 of Set 3 | volchikha
# Processing Record 48 of Set 3 | san jose de guanipa
# Processing Record 49 of Set 3 | cidreira
# Processing Record 0 of Set 4 | longyearbyen
# Processing Record 1 of Set 4 | adrar
# Processing Record 2 of Set 4 | beringovskiy
# Processing Record 3 of Set 4 | yellowknife
# Processing Record 4 of Set 4 | chapais
# Processing Record 5 of Set 4 | hermanus
# Processing Record 6 of Set 4 | gniezno
# Processing Record 7 of Set 4 | satun
# Processing Record 8 of Set 4 | bima
# Processing Record 9 of Set 4 | kahului
# Processing Record 10 of Set 4 | hithadhoo
# Processing Record 11 of Set 4 | bintulu
# Processing Record 12 of Set 4 | tuktoyaktuk
# Processing Record 13 of Set 4 | buala
# Processing Record 14 of Set 4 | lagoa
# Processing Record 15 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 4 | puyo
# Processing Record 17 of Set 4 | port elizabeth
# Processing Record 18 of Set 4 | port lincoln
# Processing Record 19 of Set 4 | luderitz
# Processing Record 20 of Set 4 | kumluca
# Processing Record 21 of Set 4 | champerico
# Processing Record 22 of Set 4 | cherskiy
# Processing Record 23 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 4 | victoria
# Processing Record 25 of Set 4 | rocha
# Processing Record 26 of Set 4 | kalmunai
# Processing Record 27 of Set 4 | batticaloa
# Processing Record 28 of Set 4 | barrow
# Processing Record 29 of Set 4 | myskhako
# Processing Record 30 of Set 4 | upernavik
# Processing Record 31 of Set 4 | gat
# Processing Record 32 of Set 4 | margate
# Processing Record 33 of Set 4 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 34 of Set 4 | fort dodge
# Processing Record 35 of Set 4 | rio grande
# Processing Record 36 of Set 4 | ribeira grande
# Processing Record 37 of Set 4 | new norfolk
# Processing Record 38 of Set 4 | vilyuysk
# Processing Record 39 of Set 4 | okha
# Processing Record 40 of Set 4 | kesennuma
# City not found. Skipping...
# Processing Record 41 of Set 4 | vardo
# Processing Record 42 of Set 4 | norman wells
# Processing Record 43 of Set 4 | nuevo progreso
# Processing Record 44 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 4 | prince rupert
# Processing Record 46 of Set 4 | colon
# Processing Record 47 of Set 4 | goksun
# Processing Record 48 of Set 4 | vegreville
# Processing Record 49 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 0 of Set 5 | boa viagem
# Processing Record 1 of Set 5 | butaritari
# Processing Record 2 of Set 5 | ust-nera
# Processing Record 3 of Set 5 | thompson
# Processing Record 4 of Set 5 | tual
# Processing Record 5 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 5 | esna
# Processing Record 7 of Set 5 | korla
# Processing Record 8 of Set 5 | chuy
# Processing Record 9 of Set 5 | rio gallegos
# Processing Record 10 of Set 5 | hobyo
# Processing Record 11 of Set 5 | kuala terengganu
# Processing Record 12 of Set 5 | samarai
# Processing Record 13 of Set 5 | pangody
# Processing Record 14 of Set 5 | melo
# Processing Record 15 of Set 5 | talnakh
# Processing Record 16 of Set 5 | tateyama
# Processing Record 17 of Set 5 | port hardy
# Processing Record 18 of Set 5 | san quintin
# Processing Record 19 of Set 5 | kibakwe
# Processing Record 20 of Set 5 | asau
# Processing Record 21 of Set 5 | russell
# Processing Record 22 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 5 | alofi
# Processing Record 24 of Set 5 | bolshaya sosnova
# Processing Record 25 of Set 5 | richards bay
# Processing Record 26 of Set 5 | whitehorse
# Processing Record 27 of Set 5 | yarmouth
# Processing Record 28 of Set 5 | malpe
# Processing Record 29 of Set 5 | burgeo
# Processing Record 30 of Set 5 | namibe
# Processing Record 31 of Set 5 | yerbogachen
# Processing Record 32 of Set 5 | truth or consequences
# Processing Record 33 of Set 5 | la paz
# Processing Record 34 of Set 5 | saint-pierre
# Processing Record 35 of Set 5 | bredasdorp
# Processing Record 36 of Set 5 | shiyan
# Processing Record 37 of Set 5 | majene
# Processing Record 38 of Set 5 | nueva guinea
# Processing Record 39 of Set 5 | koslan
# Processing Record 40 of Set 5 | yining
# Processing Record 41 of Set 5 | pashiya
# Processing Record 42 of Set 5 | dudinka
# Processing Record 43 of Set 5 | labuhan
# Processing Record 44 of Set 5 | saint george
# Processing Record 45 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 5 | clyde river
# Processing Record 47 of Set 5 | torbay
# Processing Record 48 of Set 5 | martaban
# Processing Record 49 of Set 5 | zhicheng
# Processing Record 0 of Set 6 | ogre
# Processing Record 1 of Set 6 | huarmey
# Processing Record 2 of Set 6 | kribi
# Processing Record 3 of Set 6 | arman
# Processing Record 4 of Set 6 | gorontalo
# Processing Record 5 of Set 6 | amga
# Processing Record 6 of Set 6 | vila velha
# Processing Record 7 of Set 6 | burica
# City not found. Skipping...
# Processing Record 8 of Set 6 | bubaque
# Processing Record 9 of Set 6 | san patricio
# Processing Record 10 of Set 6 | conde
# Processing Record 11 of Set 6 | pimentel
# Processing Record 12 of Set 6 | sosva
# Processing Record 13 of Set 6 | kamenka
# Processing Record 14 of Set 6 | kaeo
# Processing Record 15 of Set 6 | fairbanks
# Processing Record 16 of Set 6 | anqiu
# Processing Record 17 of Set 6 | lasa
# Processing Record 18 of Set 6 | etaples
# Processing Record 19 of Set 6 | homer
# Processing Record 20 of Set 6 | itoman
# Processing Record 21 of Set 6 | ferzikovo
# Processing Record 22 of Set 6 | viedma
# Processing Record 23 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 6 | boguchany
# Processing Record 25 of Set 6 | eyrarbakki
# Processing Record 26 of Set 6 | ilulissat
# Processing Record 27 of Set 6 | lokosovo
# Processing Record 28 of Set 6 | qinzhou
# Processing Record 29 of Set 6 | high rock
# Processing Record 30 of Set 6 | galle
# Processing Record 31 of Set 6 | xinmin
# Processing Record 32 of Set 6 | chabua
# Processing Record 33 of Set 6 | kushima
# Processing Record 34 of Set 6 | ahuimanu
# Processing Record 35 of Set 6 | veraval
# Processing Record 36 of Set 6 | portland
# Processing Record 37 of Set 6 | ancud
# Processing Record 38 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 39 of Set 6 | sao joao da barra
# Processing Record 40 of Set 6 | arawa
# Processing Record 41 of Set 6 | vostok
# Processing Record 42 of Set 6 | mahebourg
# Processing Record 43 of Set 6 | kokopo
# Processing Record 44 of Set 6 | nizhniy kuranakh
# Processing Record 45 of Set 6 | tingi
# Processing Record 46 of Set 6 | paso de carrasco
# Processing Record 47 of Set 6 | kitgum
# Processing Record 48 of Set 6 | cividale del friuli
# Processing Record 49 of Set 6 | labuan
# Processing Record 0 of Set 7 | mount gambier
# Processing Record 1 of Set 7 | sao filipe
# Processing Record 2 of Set 7 | ambon
# Processing Record 3 of Set 7 | soyo
# Processing Record 4 of Set 7 | kaitangata
# Processing Record 5 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 6 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 7 | vestmannaeyjar
# Processing Record 8 of Set 7 | praia
# Processing Record 9 of Set 7 | shenjiamen
# Processing Record 10 of Set 7 | pacific grove
# Processing Record 11 of Set 7 | hurghada
# Processing Record 12 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 7 | saint-augustin
# Processing Record 14 of Set 7 | paoua
# Processing Record 15 of Set 7 | cheyenne
# Processing Record 16 of Set 7 | taltal
# Processing Record 17 of Set 7 | khandyga
# Processing Record 18 of Set 7 | troitsko-pechorsk
# Processing Record 19 of Set 7 | ilebo
# Processing Record 20 of Set 7 | kindu
# Processing Record 21 of Set 7 | wote
# Processing Record 22 of Set 7 | parambu
# Processing Record 23 of Set 7 | baculin
# Processing Record 24 of Set 7 | panama city
# Processing Record 25 of Set 7 | nuuk
# Processing Record 26 of Set 7 | kimparana
# Processing Record 27 of Set 7 | shirokiy
# Processing Record 28 of Set 7 | saint-leu
# Processing Record 29 of Set 7 | riyadh
# Processing Record 30 of Set 7 | coquimbo
# Processing Record 31 of Set 7 | simbahan
# Processing Record 32 of Set 7 | nome
# Processing Record 33 of Set 7 | akhmim
# Processing Record 34 of Set 7 | tra vinh
# Processing Record 35 of Set 7 | buin
# Processing Record 36 of Set 7 | mehamn
# Processing Record 37 of Set 7 | las palmas
# Processing Record 38 of Set 7 | vega de alatorre
# Processing Record 39 of Set 7 | manta
# Processing Record 40 of Set 7 | conceicao do araguaia
# Processing Record 41 of Set 7 | hovd
# Processing Record 42 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 7 | ucluelet
# Processing Record 44 of Set 7 | kota kinabalu
# Processing Record 45 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 7 | takoradi
# Processing Record 48 of Set 7 | ende
# Processing Record 49 of Set 7 | nanortalik
# Processing Record 0 of Set 8 | lagos
# Processing Record 1 of Set 8 | singkang
# Processing Record 2 of Set 8 | opuwo
# Processing Record 3 of Set 8 | sinnamary
# Processing Record 4 of Set 8 | papara
# Processing Record 5 of Set 8 | fortuna
# Processing Record 6 of Set 8 | moron
# Processing Record 7 of Set 8 | bocaiuva
# Processing Record 8 of Set 8 | inuvik
# Processing Record 9 of Set 8 | berlevag
# Processing Record 10 of Set 8 | airai
# Processing Record 11 of Set 8 | navahrudak
# Processing Record 12 of Set 8 | gashua
# Processing Record 13 of Set 8 | drochia
# Processing Record 14 of Set 8 | peshkovo
# Processing Record 15 of Set 8 | xuanhua
# Processing Record 16 of Set 8 | oxford
# Processing Record 17 of Set 8 | la orilla
# Processing Record 18 of Set 8 | acapulco
# Processing Record 19 of Set 8 | troutdale
# Processing Record 20 of Set 8 | doka
# Processing Record 21 of Set 8 | aklavik
# Processing Record 22 of Set 8 | polaniec
# Processing Record 23 of Set 8 | guerrero negro
# Processing Record 24 of Set 8 | zhigansk
# Processing Record 25 of Set 8 | waipawa
# Processing Record 26 of Set 8 | griffith
# Processing Record 27 of Set 8 | kysyl-syr
# Processing Record 28 of Set 8 | oron
# Processing Record 29 of Set 8 | simao
# Processing Record 30 of Set 8 | kemijarvi
# Processing Record 31 of Set 8 | skibbereen
# Processing Record 32 of Set 8 | bandarbeyla
# Processing Record 33 of Set 8 | manaure
# Processing Record 34 of Set 8 | dalbandin
# Processing Record 35 of Set 8 | mikhaylovka
# Processing Record 36 of Set 8 | pietarsaari
# Processing Record 37 of Set 8 | syracuse
# Processing Record 38 of Set 8 | half moon bay
# Processing Record 39 of Set 8 | tiznit
# Processing Record 40 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 41 of Set 8 | padang
# Processing Record 42 of Set 8 | concepcion del uruguay
# Processing Record 43 of Set 8 | los llanos de aridane
# Processing Record 44 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 8 | killybegs
# Processing Record 46 of Set 8 | pangnirtung
# Processing Record 47 of Set 8 | severo-kurilsk
# Processing Record 48 of Set 8 | wanning
# Processing Record 49 of Set 8 | quatre cocos
# Processing Record 0 of Set 9 | kudahuvadhoo
# Processing Record 1 of Set 9 | awbari
# Processing Record 2 of Set 9 | scottsbluff
# Processing Record 3 of Set 9 | tommot
# Processing Record 4 of Set 9 | wallasey
# Processing Record 5 of Set 9 | uinskoye
# Processing Record 6 of Set 9 | krasnyy luch
# Processing Record 7 of Set 9 | strezhevoy
# Processing Record 8 of Set 9 | wamba
# Processing Record 9 of Set 9 | saint-louis
# Processing Record 10 of Set 9 | batagay
# Processing Record 11 of Set 9 | carney
# Processing Record 12 of Set 9 | nkan
# Processing Record 13 of Set 9 | dujuma
# City not found. Skipping...
# Processing Record 14 of Set 9 | abu dhabi
# Processing Record 15 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 9 | uspenka
# Processing Record 17 of Set 9 | havoysund
# Processing Record 18 of Set 9 | fort-shevchenko
# Processing Record 19 of Set 9 | waingapu
# Processing Record 20 of Set 9 | teahupoo
# Processing Record 21 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 9 | ryde
# Processing Record 23 of Set 9 | red bluff
# Processing Record 24 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 25 of Set 9 | staryy biser
# City not found. Skipping...
# Processing Record 26 of Set 9 | adiake
# Processing Record 27 of Set 9 | zawiercie
# Processing Record 28 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 9 | katobu
# Processing Record 30 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 9 | nemuro
# Processing Record 32 of Set 9 | touros
# Processing Record 33 of Set 9 | villanueva de la serena
# Processing Record 34 of Set 9 | brae
# Processing Record 35 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 36 of Set 9 | handwara
# City not found. Skipping...
# Processing Record 37 of Set 9 | senneterre
# Processing Record 38 of Set 9 | sola
# Processing Record 39 of Set 9 | cabedelo
# Processing Record 40 of Set 9 | pahrump
# Processing Record 41 of Set 9 | vestmanna
# Processing Record 42 of Set 9 | plakhtiyivka
# Processing Record 43 of Set 9 | nha trang
# Processing Record 44 of Set 9 | nabire
# Processing Record 45 of Set 9 | husavik
# Processing Record 46 of Set 9 | ampanihy
# Processing Record 47 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 9 | morondava
# Processing Record 49 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 0 of Set 10 | kizhinga
# Processing Record 1 of Set 10 | araouane
# Processing Record 2 of Set 10 | suzun
# Processing Record 3 of Set 10 | edgewood
# Processing Record 4 of Set 10 | faya
# Processing Record 5 of Set 10 | huambo
# Processing Record 6 of Set 10 | jijiga
# Processing Record 7 of Set 10 | bairiki
# Processing Record 8 of Set 10 | ciudad bolivar
# Processing Record 9 of Set 10 | vanimo
# Processing Record 10 of Set 10 | omsukchan
# Processing Record 11 of Set 10 | mgachi
# Processing Record 12 of Set 10 | wanaka
# Processing Record 13 of Set 10 | kokoda
# Processing Record 14 of Set 10 | kandi
# Processing Record 15 of Set 10 | luanda
# Processing Record 16 of Set 10 | wajir
# Processing Record 17 of Set 10 | salalah
# Processing Record 18 of Set 10 | lavrentiya
# Processing Record 19 of Set 10 | ust-tsilma
# Processing Record 20 of Set 10 | kirkwall
# Processing Record 21 of Set 10 | goderich
# Processing Record 22 of Set 10 | yandyki
# Processing Record 23 of Set 10 | jinchang
# Processing Record 24 of Set 10 | anloga
# Processing Record 25 of Set 10 | novikovo
# Processing Record 26 of Set 10 | rumuruti
# Processing Record 27 of Set 10 | dergachi
# Processing Record 28 of Set 10 | media luna
# Processing Record 29 of Set 10 | severo-yeniseyskiy
# Processing Record 30 of Set 10 | north adams
# Processing Record 31 of Set 10 | baft
# Processing Record 32 of Set 10 | edd
# Processing Record 33 of Set 10 | marawi
# Processing Record 34 of Set 10 | muli
# Processing Record 35 of Set 10 | mount isa
# Processing Record 36 of Set 10 | ritchie
# Processing Record 37 of Set 10 | banjar
# Processing Record 38 of Set 10 | tura
# Processing Record 39 of Set 10 | batagay-alyta
# Processing Record 40 of Set 10 | baghdad
# Processing Record 41 of Set 10 | general pico
# Processing Record 42 of Set 10 | cacule
# Processing Record 43 of Set 10 | mustasaari
# Processing Record 44 of Set 10 | cayenne
# Processing Record 45 of Set 10 | severobaykalsk
# Processing Record 46 of Set 10 | komsomolskiy
# Processing Record 47 of Set 10 | beruwala
# Processing Record 48 of Set 10 | hun
# Processing Record 49 of Set 10 | ishigaki
# Processing Record 0 of Set 11 | mnogovershinnyy
# Processing Record 1 of Set 11 | lazaro cardenas
# Processing Record 2 of Set 11 | puerto baquerizo moreno
# Processing Record 3 of Set 11 | kalmar
# Processing Record 4 of Set 11 | monteagudo
# Processing Record 5 of Set 11 | karratha
# Processing Record 6 of Set 11 | christchurch
# Processing Record 7 of Set 11 | kandrian
# Processing Record 8 of Set 11 | chuguyevka
# Processing Record 9 of Set 11 | sistranda
# Processing Record 10 of Set 11 | baruun-urt
# Processing Record 11 of Set 11 | mabaruma
# Processing Record 12 of Set 11 | davila
# Processing Record 13 of Set 11 | brenham
# Processing Record 14 of Set 11 | paldiski
# Processing Record 15 of Set 11 | cabras
# Processing Record 16 of Set 11 | mul
# Processing Record 17 of Set 11 | te anau
# Processing Record 18 of Set 11 | payo
# Processing Record 19 of Set 11 | necochea
# Processing Record 20 of Set 11 | ixtapa
# Processing Record 21 of Set 11 | lompoc
# Processing Record 22 of Set 11 | vaitape
# Processing Record 23 of Set 11 | san cristobal
# Processing Record 24 of Set 11 | uyskoye
# Processing Record 25 of Set 11 | venado tuerto
# Processing Record 26 of Set 11 | honiara
# Processing Record 27 of Set 11 | beyneu
# Processing Record 28 of Set 11 | palimbang
# Processing Record 29 of Set 11 | ahumada
# City not found. Skipping...
# Processing Record 30 of Set 11 | selma
# Processing Record 31 of Set 11 | liberal
# Processing Record 32 of Set 11 | alasehir
# Processing Record 33 of Set 11 | ponta delgada
# Processing Record 34 of Set 11 | bilma
# Processing Record 35 of Set 11 | bilibino
# Processing Record 36 of Set 11 | olafsvik
# Processing Record 37 of Set 11 | wakkanai
# Processing Record 38 of Set 11 | baglung
# Processing Record 39 of Set 11 | cartagena
# Processing Record 40 of Set 11 | langsa
# Processing Record 41 of Set 11 | bangassou
# Processing Record 42 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 11 | santa isabel do rio negro
# Processing Record 44 of Set 11 | itarema
# Processing Record 45 of Set 11 | keningau
# Processing Record 46 of Set 11 | erzin
# Processing Record 47 of Set 11 | zyryanka
# Processing Record 48 of Set 11 | sisimiut
# Processing Record 49 of Set 11 | sitka
# Processing Record 0 of Set 12 | saldanha
# Processing Record 1 of Set 12 | yulara
# Processing Record 2 of Set 12 | krasnoselkup
# Processing Record 3 of Set 12 | yashkul
# Processing Record 4 of Set 12 | olavarria
# Processing Record 5 of Set 12 | awjilah
# Processing Record 6 of Set 12 | turtas
# Processing Record 7 of Set 12 | blythe
# Processing Record 8 of Set 12 | medea
# Processing Record 9 of Set 12 | rohatyn
# Processing Record 10 of Set 12 | san carlos
# Processing Record 11 of Set 12 | newport
# Processing Record 12 of Set 12 | yongan
# Processing Record 13 of Set 12 | morant bay
# Processing Record 14 of Set 12 | ulaangom
# Processing Record 15 of Set 12 | caluquembe
# Processing Record 16 of Set 12 | tarare
# Processing Record 17 of Set 12 | lujan
# Processing Record 18 of Set 12 | aykhal
# Processing Record 19 of Set 12 | quelimane
# Processing Record 20 of Set 12 | yeletskiy
# City not found. Skipping...
# Processing Record 21 of Set 12 | luwuk
# Processing Record 22 of Set 12 | san buenaventura
# Processing Record 23 of Set 12 | rancho veloz
# Processing Record 24 of Set 12 | sur
# Processing Record 25 of Set 12 | basco
# Processing Record 26 of Set 12 | veisiejai
# Processing Record 27 of Set 12 | port macquarie
# Processing Record 28 of Set 12 | wampusirpi
# City not found. Skipping...
# Processing Record 29 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 12 | gizo
# Processing Record 31 of Set 12 | la ronge
# Processing Record 32 of Set 12 | cangzhou
# Processing Record 33 of Set 12 | gravdal
# Processing Record 34 of Set 12 | balkhash
# Processing Record 35 of Set 12 | sobolevo
# Processing Record 36 of Set 12 | wahiawa
# Processing Record 37 of Set 12 | grand gaube
# Processing Record 38 of Set 12 | skjervoy
# Processing Record 39 of Set 12 | camara de lobos
# Processing Record 40 of Set 12 | kailua
# Processing Record 41 of Set 12 | hay river
# Processing Record 42 of Set 12 | sorland
# Processing Record 43 of Set 12 | neiafu
# Processing Record 44 of Set 12 | pasir mas
# Processing Record 45 of Set 12 | galanta
# Processing Record 46 of Set 12 | mackay
# Processing Record 47 of Set 12 | villa carlos paz
# Processing Record 48 of Set 12 | cam ranh
# Processing Record 49 of Set 12 | chalmette
# Processing Record 0 of Set 13 | batemans bay
# Processing Record 1 of Set 13 | varca
# Processing Record 2 of Set 13 | santa vitoria do palmar
# Processing Record 3 of Set 13 | sioux lookout
# Processing Record 4 of Set 13 | san luis
# Processing Record 5 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 6 of Set 13 | santa cruz de la palma
# Processing Record 7 of Set 13 | pelotas
# Processing Record 8 of Set 13 | safaga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          560
# Lat           560
# Lng           560
# Max Temp      560
# Humidity      560
# Cloudiness    560
# Wind Speed    560
# Country       560
# Date          560
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     maragogi  -9.0122  -35.2225     28.41        70         100        4.69
# 1       hobart -42.8794  147.3294     14.59        87         100        0.51
# 2      birjand  32.8663   59.2211     18.26        24          40        4.12
# 3        vaini -21.2000 -175.2000     25.09       100          75        2.06
# 4  port-gentil  -0.7193    8.7815     28.98        79          20        5.14
#
#   Country        Date
# 0      BR  1680890367
# 1      AU  1680890338
# 2      IR  1680890368
# 3      TO  1680890368
# 4      GA  1680890369

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           maragogi  -9.0122  -35.2225     28.41        70         100
# 1             hobart -42.8794  147.3294     14.59        87         100
# 2            birjand  32.8663   59.2211     18.26        24          40
# 3              vaini -21.2000 -175.2000     25.09       100          75
# 4        port-gentil  -0.7193    8.7815     28.98        79          20
#
#          Wind Speed Country        Date
# City_ID
# 0              4.69      BR  1680890367
# 1              0.51      AU  1680890338
# 2              4.12      IR  1680890368
# 3              2.06      TO  1680890368
# 4              5.14      GA  1680890369

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot('Lat','Max Temp',kind='scatter')
# Incorporate the other graph properties
max_date = pd.to_datetime(city_data_df['Date'].max(), unit='s').date()
plt.title("Latitude vs Max Temperature ("+str(max_date)+")")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (C)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
city_data_df.plot('Lat','Humidity',kind='scatter')

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity ("+str(max_date)+")")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot('Lat','Cloudiness',kind='scatter')

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness ("+str(max_date)+")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot('Lat','Wind Speed',kind='scatter')

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed ("+str(max_date)+")")
plt.xlabel("city Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def draw_regression_line(x_values,y_values,x,y):
    slope, intercept, rval, pval, std_err = linregress(x_values,y_values)
    print(f"The r-squared value is: {rval**2}")
    fit = slope * x_values  + intercept
    line_eq=f"y = {round(slope,2)}x + {round(intercept,2)}"
    plt.scatter(x_values,y_values)
    plt.annotate(line_eq,(x,y),fontsize=15,color="red")
    plt.xlabel("Latitude")
    return plt.plot(x_values,fit,'-', color='r')

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0,:]
# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2            birjand  32.8663   59.2211     18.26        24          40
# 5             narsaq  60.9167  -46.0500      0.90        63          34
# 6             dikson  73.5069   80.5464    -31.50       100          87
# 8        meadow lake  34.8014 -106.5436     16.02        18          46
# 9         solnechnyy  50.7214  136.6319     -3.04        89         100
#
#          Wind Speed Country        Date
# City_ID
# 2              4.12      IR  1680890368
# 5              2.25      GL  1680890369
# 6              4.25      RU  1680890370
# 8              2.41      US  1680890371
# 9              2.46      RU  1680890371

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0,:]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           maragogi  -9.0122  -35.2225     28.41        70         100
# 1             hobart -42.8794  147.3294     14.59        87         100
# 3              vaini -21.2000 -175.2000     25.09       100          75
# 4        port-gentil  -0.7193    8.7815     28.98        79          20
# 7             atuona  -9.8000 -139.0333     26.92        72          66
#
#          Wind Speed Country        Date
# City_ID
# 0              4.69      BR  1680890367
# 1              0.51      AU  1680890338
# 3              2.06      TO  1680890368
# 4              5.14      GA  1680890369
# 7              8.75      PF  1680890370

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
draw_regression_line(northern_hemi_df['Lat'],northern_hemi_df["Max Temp"],10,-20)
plt.ylabel("Max Temperature")
plt.show()
# Out:
# The r-squared value is: 0.7462576393994135

# %%
# Linear regression on Southern Hemisphere
draw_regression_line(southern_hemi_df['Lat'],southern_hemi_df["Max Temp"],-55,30)
plt.ylabel("Max Temperature")
plt.show()
# Out:
# The r-squared value is: 0.4242000817949292

# %% [markdown]
# **Discussion about the linear relationship:** Temperature variations in the northern hemishpere have a higher linear relationship with latititudes (74.62%) as compared to the relationship between temperatures and latitude in the southern hemisphere (42.42%).

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
draw_regression_line(northern_hemi_df['Lat'],northern_hemi_df["Humidity"],40,0)
plt.ylabel("Humidity")
plt.show()
# Out:
# The r-squared value is: 0.12215491345091328

# %%
# Southern Hemisphere
draw_regression_line(southern_hemi_df['Lat'],southern_hemi_df["Humidity"],-50,20)
plt.ylabel("Humidity")
plt.show()
# Out:
# The r-squared value is: 0.08585305394441654

# %% [markdown]
# **Discussion about the linear relationship:** Only 12.21% of variations in humidity in the northern hemisphere are accounted for by the change in latitude while only 8.58% of hunidity variations in the southern hemisphere and be accounted for changes in latitude. Small linear relationship between humidity and latitude in both the hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
#Northern Hemisphere
draw_regression_line(northern_hemi_df['Lat'],northern_hemi_df["Cloudiness"],40,55)
plt.ylabel("Cloudiness")
plt.show()
# Out:
# The r-squared value is: 0.04429493786968051

# %%
#Southern Hemisphere
draw_regression_line(southern_hemi_df['Lat'],southern_hemi_df["Cloudiness"],-52,60)
plt.ylabel("Cloudiness")
plt.show()
# Out:
# The r-squared value is: 0.13010713351728517

# %% [markdown]
# **Discussion about the linear relationship:** Only 4.42% of cloudiness variations can be accounted for by changes in the northern hemishpere lattitudes, while onlt 13% of cloudiness variations can be accounted for by the changes in a Southern hemisphere latitude changes, very small linear relationship between cloudiness and latitude in both the hemishperes.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
draw_regression_line(northern_hemi_df['Lat'],northern_hemi_df["Wind Speed"],10,12)
plt.ylabel("Wind Speed")
plt.show()
# Out:
# The r-squared value is: 0.009637912861875908

# %%
# Southern Hemisphere
draw_regression_line(southern_hemi_df['Lat'],southern_hemi_df["Wind Speed"],-50,9)
plt.ylabel("Wind Speed")
plt.show()
# Out:
# The r-squared value is: 0.07733285242673965

# %% [markdown]
# **Discussion about the linear relationship:** Only 0.96% of variations in wind speed is accounted for with change in the northern hemisphere latitdude and 7.73% of variations in wind speed is accounted for changes in the southern hemisphere latitude, very low linear relationship between wind speed and latitude in both the hemispheres.
